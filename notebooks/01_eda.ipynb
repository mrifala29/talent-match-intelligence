# %%
from src.data_loader import fetch_table

data = fetch_table("employees", limit=5)
print(data)
# Out:
# ---------------------------------------------------------------------------
# SupabaseException                         Traceback (most recent call last)
# Cell In[6], line 3
#       1 from src.data_loader import fetch_table
# ----> 3 data = fetch_table("employees", limit=5)
#       4 print(data)
#
# File c:\Users\M S I\Desktop\Bismillah Kerja\Rakamin\talent-match-intelligence\src\data_loader.py:8, in fetch_table(table_name, limit)
#       7 def fetch_table(table_name, limit=5):
# ----> 8     supabase = get_supabase_client()
#       9     response = supabase.table(table_name).select("*").limit(limit).execute()
#      10     return response.data
#
# File c:\Users\M S I\Desktop\Bismillah Kerja\Rakamin\talent-match-intelligence\src\data_loader.py:5, in get_supabase_client()
#       4 def get_supabase_client():
# ----> 5     return create_client(SUPABASE_URL, SUPABASE_KEY)
#
# ...
